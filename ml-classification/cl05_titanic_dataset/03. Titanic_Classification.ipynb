# %%
import pandas as pd
from pandas import isnull

# %% [markdown]
# **Dataset #3**

# %%
c=pd.read_csv("titanic.csv")
print(c)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
c.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
c.fillna(0,inplace=True)

# %%
c.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
c.duplicated().sum()
# Out:
# np.int64(0)

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
c['Name']=le.fit_transform(c['Name'])

# %%
#label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
c['Sex']=le.fit_transform(c['Sex'])

# %%
#label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
c['Ticket']=le.fit_transform(c['Ticket'])

# %%
#label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
c['Cabin'] = c['Cabin'].astype(str)
c['Cabin']=le.fit_transform(c['Cabin'])

# %%
#label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
c['Cabin'] = c['Cabin'].astype(str)
c['Cabin']=le.fit_transform(c['Cabin'])

# %%
#label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
c['Embarked']=c['Embarked'].astype(str)
c['Embarked']=le.fit_transform(c['Embarked'])

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    int64
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    int64
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    int64
#  11  Embarked     891 non-null    int64
# dtypes: float64(2), int64(10)
# memory usage: 83.7 KB

# %%
c.head(10)
# Out:
#    PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0            1         0       3   108    1  22.0      1      0     523
# 1            2         1       1   190    0  38.0      1      0     596
# 2            3         1       3   353    0  26.0      0      0     669
# 3            4         1       1   272    0  35.0      1      0      49
# 4            5         0       3    15    1  35.0      0      0     472
# 5            6         0       3   554    1   0.0      0      0     275
# 6            7         0       1   515    1  54.0      0      0      85
# 7            8         0       3   624    1   2.0      3      1     395
# 8            9         1       3   412    0  27.0      0      2     344
# 9           10         1       2   576    0  14.0      1      0     132
#
#       Fare  Cabin  Embarked
# 0   7.2500      0         3
# 1  71.2833    129         1
# 2   7.9250      0         3
# 3  53.1000    100         3
# 4   8.0500      0         3
# ...

# %%
c.tail()
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 886          887         0       2   548    1  27.0      0      0     101
# 887          888         1       1   303    0  19.0      0      0      14
# 888          889         0       3   413    0   0.0      1      2     675
# 889          890         1       1    81    1  26.0      0      0       8
# 890          891         0       3   220    1  32.0      0      0     466
#
#       Fare  Cabin  Embarked
# 886  13.00      0         3
# 887  30.00     73         3
# 888  23.45      0         3
# 889  30.00    106         1
# 890   7.75      0         2

# %%
c.shape
# Out:
# (891, 12)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Survived', data=c)
plt.title("Survival Count (0 = No, 1 = Yes)")
plt.show()

# %%
sns.countplot(x='Sex', hue='Survived', data=c)
plt.title("Survival by Gender")
plt.show()

# %%
sns.countplot(x='Pclass', hue='Survived', data=c)
plt.title("Survival by Class")
plt.show()

# %%
sns.histplot(c['Age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(c.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.boxplot(x='Survived', y='Age', data=c)
plt.title("Age vs Survival")
plt.show()

# %%
x=c.drop("Survived",axis=1)
y=c["Survived"]
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %%
# Impute missing values with the mean
imputer = SimpleImputer(strategy='mean') #impute module used to handle missing data. 'mean' specifies that missing values in the dataset should be replaced by the mean (average) value of the respective column.
x = imputer.fit_transform(x)

# %%
import numpy as np
np.isnan(x).sum()
# Out:
# np.int64(0)

# %%
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (712, 11)
# (179, 11)
# (712,)
# (179,)

# %%
# Standardize features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.fit_transform(xtest)

# %%
print(xtrain)
# Out:
# [[-1.48988414  0.8370107   1.20310421 ... -0.10279894 -0.47818302
#    0.59308219]
#  [-1.49761247 -1.52787667 -0.22917306 ...  0.94251712  1.19781148
#   -3.10028098]
#  [-1.5864882   0.8370107   1.52052782 ... -0.30142906 -0.47818302
#    0.59308219]
#  ...
#  [-1.45510668 -0.34543299 -0.26401224 ...  0.81210341 -0.47818302
#    0.59308219]
#  [-0.60499102 -0.34543299  0.12696075 ... -0.40425525  3.21964611
#   -1.86915992]
#  [-0.07173665 -1.52787667 -1.36338182 ... -0.12988487  2.66098128
#    0.59308219]]

# %%
print(xtest)
# Out:
# [[ 0.48407887  0.79128729  0.60086987 ... -0.43248505 -0.38875063
#   -0.77089244]
#  [ 0.9035276   0.79128729 -1.37001514 ... -0.27537331 -0.38875063
#   -0.77089244]
#  [-0.0512176  -0.47335936  0.25655863 ... -0.32657779 -0.38875063
#    0.56881384]
#  ...
#  [-0.70635657  0.79128729  1.00454511 ... -0.17885285 -0.38875063
#    0.56881384]
#  [-0.85416231 -0.47335936 -0.23022622 ... -0.03983268 -0.38875063
#    0.56881384]
#  [-1.32154804  0.79128729  0.82249549 ... -0.43112096 -0.38875063
#    0.56881384]]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Impute NaNs in xtrain and xtest before fitting the model.
# The 'imputer' object has already been fitted on a version of 'x' in a previous cell.
#xtrain_imputed = imputer.transform(xtrain)
#xtest_imputed = imputer.transform(xtest)

model = LogisticRegression()
model.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
ypred = model.predict(xtest)

# %%
# Calculate accuracy
accuracy = accuracy_score(ytest, ypred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 75.98%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate confusion matrix
cm = confusion_matrix(ytest, ypred)

# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Survived', 'Survived'], yticklabels=['Not Survived', 'Survived'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix for Titanic Survival Prediction')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for Titanic Survival Prediction')

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(ytest, ypred))
# Out:
# 0.7094972067039106

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(
    criterion='entropy',
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=5,
    max_features='sqrt',
    max_leaf_nodes=20,
    splitter='best',
    class_weight='balanced',
    random_state=42,
    ccp_alpha=0.01
)

# %%
model.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.01, class_weight='balanced',
#                        criterion='entropy', max_depth=5, max_features='sqrt',
#                        max_leaf_nodes=20, min_samples_leaf=5,
#                        min_samples_split=10, random_state=42)

# %%
ypred = model.predict(xtest)
print(model.criterion, accuracy_score(ytest, ypred))
# Out:
# entropy 0.6815642458100558

# %%
from sklearn.metrics import accuracy_score

for crit in ['gini', 'entropy', 'log_loss']:
    model = DecisionTreeClassifier(criterion=crit)
    model.fit(xtrain, ytrain)
    ypred = model.predict(xtest)
    print(crit, accuracy_score(ytest, ypred))
# Out:
# gini 0.7094972067039106
# entropy 0.7486033519553073
# log_loss 0.7318435754189944

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100)
model.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier()

# %%
ypred=model.predict(xtest)
print(accuracy_score(ytest,ypred))
# Out:
# 0.7597765363128491

# %%
# Generate confusion matrix
cm = confusion_matrix(ytest, ypred)

# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Survived', 'Survived'], yticklabels=['Not Survived', 'Survived'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix for Titanic Survival Prediction')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for Titanic Survival Prediction')

# %%
from sklearn.metrics import classification_report
ypred=model.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       107
#            1       0.71      0.68      0.70        72
#
#     accuracy                           0.76       179
#    macro avg       0.75      0.75      0.75       179
# weighted avg       0.76      0.76      0.76       179

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=1000)
model.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
ypred=model.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.82      0.80       107
#            1       0.71      0.65      0.68        72
#
#     accuracy                           0.75       179
#    macro avg       0.75      0.74      0.74       179
# weighted avg       0.75      0.75      0.75       179

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=5)
model.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(n_estimators=5)

# %%
ypred=model.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.75      0.77       107
#            1       0.65      0.69      0.67        72
#
#     accuracy                           0.73       179
#    macro avg       0.72      0.72      0.72       179
# weighted avg       0.73      0.73      0.73       179

# %%
from sklearn.svm import SVC

model = SVC(kernel = 'rbf')
model.fit(xtrain, ytrain)
# Out:
# SVC()

# %%
ypred=model.predict(xtest)
print(accuracy_score(ytest,ypred))
# Out:
# 0.7486033519553073

# %%
# Generate confusion matrix
cm = confusion_matrix(ytest, ypred)

# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Survived', 'Survived'], yticklabels=['Not Survived', 'Survived'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix for Titanic Survival Prediction')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for Titanic Survival Prediction')

# %%
from sklearn.metrics import classification_report
ypred=model.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.81      0.79       107
#            1       0.70      0.65      0.68        72
#
#     accuracy                           0.75       179
#    macro avg       0.74      0.73      0.74       179
# weighted avg       0.75      0.75      0.75       179

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(xtrain, ytrain)
# Out:
# GaussianNB()

# %%
ypred = model.predict(xtest)
print(accuracy_score(ytest,ypred))
# Out:
# 0.7932960893854749

# %%
# Generate confusion matrix
cm = confusion_matrix(ytest, ypred)

# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Survived', 'Survived'], yticklabels=['Not Survived', 'Survived'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix for Titanic Survival Prediction')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix for Titanic Survival Prediction')

# %%
from sklearn.metrics import classification_report
ypred=model.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       107
#            1       0.79      0.67      0.72        72
#
#     accuracy                           0.79       179
#    macro avg       0.79      0.77      0.78       179
# weighted avg       0.79      0.79      0.79       179

# %%
model.predict_proba(xtest)
# Out:
# array([[9.75006635e-01, 2.49933649e-02],
#        [3.63932375e-01, 6.36067625e-01],
#        [9.50807726e-01, 4.91922736e-02],
#        [9.81039647e-01, 1.89603533e-02],
#        [5.86782335e-02, 9.41321766e-01],
#        [9.47366608e-01, 5.26333923e-02],
#        [9.37442581e-01, 6.25574187e-02],
#        [1.97251407e-02, 9.80274859e-01],
#        [1.95695345e-01, 8.04304655e-01],
#        [9.81872609e-01, 1.81273912e-02],
#        [1.86678008e-01, 8.13321992e-01],
#        [4.80497073e-01, 5.19502927e-01],
#        [4.45831192e-01, 5.54168808e-01],
#        [6.76135103e-01, 3.23864897e-01],
#        [2.43108257e-01, 7.56891743e-01],
#        [9.80801424e-01, 1.91985762e-02],
#        [9.76801905e-01, 2.31980950e-02],
#        [9.39412903e-01, 6.05870966e-02],
#        [4.42532623e-03, 9.95574674e-01],
#        [2.44514525e-01, 7.55485475e-01],
#        [2.43385734e-01, 7.56614266e-01],
#        [9.87737246e-01, 1.22627541e-02],
#        [9.81213995e-01, 1.87860050e-02],
# ...

# %%
feature_names = c.drop('Survived', axis=1).columns

# %%
xtest_df = pd.DataFrame(xtest, columns=feature_names)

# %%
xtest_df['Predicted_Outcome'] = ypred

# %%
display(xtest_df.head())
# Out:
#    PassengerId    Pclass      Name       Sex       Age     SibSp     Parch  \
# 0     0.484079  0.791287  0.600870  0.820303 -1.309567 -0.445025 -0.487305
# 1     0.903528  0.791287 -1.370015 -1.219062  0.514211  0.393496  0.854658
# 2    -0.051218 -0.473359  0.256559  0.820303  0.400225 -0.445025 -0.487305
# 3    -1.073874  0.791287 -1.449167  0.820303  0.172253 -0.445025 -0.487305
# 4     0.072620 -1.738006  0.842283  0.820303  1.654072 -0.445025 -0.487305
#
#      Ticket      Fare     Cabin  Embarked  Predicted_Outcome
# 0 -0.293026 -0.432485 -0.388751 -0.770892                  0
# 1  0.495524 -0.275373 -0.388751 -0.770892                  1
# 2 -0.601134 -0.326578 -0.388751  0.568814                  0
# 3 -0.089361 -0.433595 -0.388751  0.568814                  0
# 4 -1.567237  0.031854  2.231426  0.568814                  1
