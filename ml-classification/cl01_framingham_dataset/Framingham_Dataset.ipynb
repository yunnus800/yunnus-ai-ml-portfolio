# %%
import pandas as pd
from pandas import isnull

# %%
a=pd.read_csv("framingham.csv")
print(a)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4135 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4211 non-null   float64
#  5   BPMeds           4187 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4190 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4221 non-null   float64
#  13  heartRate        4239 non-null   float64
#  14  glucose          3852 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
a.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
a.tail(2)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 4238                0             1         0    185.0  141.0   98.0  25.60
# 4239                0             0         0    196.0  133.0   86.0  20.91
#
#       heartRate  glucose  TenYearCHD
# 4238       67.0     72.0           0
# 4239       85.0     80.0           0

# %%
a.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
a.fillna(0,inplace=True)

# %%
a.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
a.duplicated().sum()
# Out:
# np.int64(0)

# %%
a.shape
# Out:
# (4240, 16)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.bar(a['age'],a['BMI'])
plt.show()

# %%
plt.pie(a['age'], labels=a['BMI'])
plt.show()

# %%
plt.pie(a['heartRate'], labels=a['glucose'])
plt.show()

# %%
plt.hist(a['BMI'])
plt.show()

# %%
plt.scatter(a['age'], a['BMI'])
plt.show()

# %%
plt.boxplot(a['BMI'])
plt.show()

# %%
plt.plot(a['glucose'], a['age'])
plt.show()

# %%
import seaborn as sns

# %%
sns.heatmap(a[['glucose','heartRate','diaBP']].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(a)
plt.show()

# %%
plt.boxplot(a['BMI'])
plt.show()

# %%
sns.lmplot(x='age',y='BMI',data=a)
plt.show()

# %%
sns.barplot(data=a)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(25, 12))

# 1. LINE PLOT
ax1 = plt.subplot(3, 3, 1)
months = np.arange(1, 13) # Corrected from np.a
ax1.plot(months, [20,22,25,28,30,32,35,38,40,42,45,48], marker='s', alpha=0.1, color='red')
ax1.set_title('Line Plot')

plt.tight_layout()
plt.show()

# %%
# 2. BAR PLOT
plt.figure()
plt.bar(a['age'], a['BMI'])
plt.title('Bar Plot: Age vs BMI')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.show()

# 3. HORIZONTAL BAR PLOT
plt.figure()
# 'regions' and 'sales' columns not found in DataFrame 'a'.
# Replacing with 'education' and 'TenYearCHD' as an example.
plt.barh(a['education'], a['TenYearCHD'])
plt.title('Horizontal Bar Plot: Education vs TenYearCHD')
plt.xlabel('TenYearCHD')
plt.ylabel('Education')

plt.tight_layout()
plt.show()

# %%
# 3. PIE CHART
ax3 = plt.subplot(2, 2, 2)
#ax3.pie(sales, labels=products)
ax3.set_title('Pie Chart')

ax3.pie(a['age'], labels=a['heartRate'], autopct='%d%%')

plt.tight_layout()
plt.show()

# %%
# 4. SCATTER PLOT
fig = plt.figure(figsize=(15, 12))
ax4 = plt.subplot(3,3,3)
#ax4.scatter(region_sales, [1,2,3,4])
ax4.set_title('Scatter Plot: BMI vs Age')

ax4.set_xlabel('BMI')
ax4.set_ylabel('Age')

ax4.scatter(a['BMI'], a['age'])

plt.tight_layout()
plt.show()

# %%
# 5. HISTOGRAM

import seaborn as sns
fig = plt.figure(figsize=(25, 10))
ax5 = plt.subplot(2, 3, 5)
daily_sales = np.random.normal(10, 2, 2000)
#ax5.hist(daily_sales, bins=10)
ax5.set_title('Histogram')
sns.kdeplot(a['BMI'], ax=ax5)
ax5.hist(a['BMI'], bins=10, color='yellow', edgecolor='red', density=True)

plt.tight_layout()
plt.show()

# %%
# 6. BOX PLOT
fig = plt.figure(figsize=(25, 20))
ax6 = plt.subplot(6, 6, 6)
#ax6.boxplot([sales, sales, sales, sales])
ax6.set_title('Box Plot')
ax6.boxplot(a['BMI'], notch=True, showmeans=True, patch_artist=True,
            boxprops=dict(facecolor='red'))


plt.tight_layout()
plt.show()

# %%
# 7. AREA PLOT - Cumulative sales
ax7 = plt.subplot(3, 3, 7)
ax7.fill_between(a['BMI'], a['age'], alpha=0.4, color='green', label='Cumulative')
ax7.plot(a['BMI'], a['age'], 'g-', linewidth=2)
ax7.set_title('Area Plot - Cumulative Sales')
ax7.legend()

# %%
# 8. HORIZONTAL BAR
ax8 = plt.subplot(3, 3, 8)
ax8.barh(a['BMI'], a['age'], color='coral', alpha=0.8)
ax8.set_title('Horizontal Bar - Region Sales')
# Out:
# Text(0.5, 1.0, 'Horizontal Bar - Region Sales')

# %%
#9. DOUGHNUT (Pie with center circle)

#plt.figure(figsize=(25, 12))
#ax9 = plt.subplot(3, 3, 1)
#ax9.pie(a['education'], labels=a['education'], autopct='%1.1f%%',
                                  #pctdistance=0.8, wedgeprops={"width":0.5})#dict(width=0.5))
#ax9.set_title('Doughnut Chart')

#plt.suptitle('Complete Matplotlib Visuals Demo', fontsize=16, fontweight='bold')
#plt.tight_layout()
#plt.show()

# Save without display
#plt.savefig('all_matplotlib_visuals.png', dpi=300, bbox_inches='tight')
#plt.close()
# Out:
#   File "/tmp/ipykernel_4628/527299239.py", line 6
#     pctdistance=0.8, wedgeprops={"width":0.5})#dict(width=0.5))
#                                              ^
# SyntaxError: unmatched ')'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(a, x='BMI',
             bins=8,
             kde=True,
             color='skyblue',
             alpha=0.7)

plt.title("Histogram - BMI Distribution")
plt.xlabel("BMI")
plt.ylabel("age")
plt.show()

# %%
sns.boxplot(data=a, x='age', y='male',
            # The 'Gender' column is not in the DataFrame 'a'. Assuming it's a placeholder, remove or replace.
            # hue='Gender',
            palette='Set2',
            linewidth=1.2)

plt.title("Box Plot - Score by BMI")
plt.xlabel("age")
plt.ylabel("male")
plt.show()
# Out:
# /tmp/ipykernel_4628/2529204691.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=a, x='age', y='male',

# %%
sns.boxplot(data=a, x='age', y='education',
            # The 'Gender' column is not in the DataFrame 'a'. Assuming it's a placeholder, remove or replace.
            # hue='Gender',
            palette='Set2',
            linewidth=1.2)

plt.title("Box Plot - Score by BMI")
plt.xlabel("age")
plt.ylabel("education")
plt.show()
# Out:
# /tmp/ipykernel_4628/656368056.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=a, x='age', y='education',

# %%
df_num = a[['BMI', 'age']]
sns.heatmap(df_num.corr(),
            annot=True,        # show numbers in each cell
            cmap='coolwarm',   # color scheme (blue–red with white in middle)
            linewidths=0.5)    # thin lines between cells

plt.title("Heatmap - Correlation")
plt.show()

# %%
df_num = a[['age', 'education']]
sns.heatmap(df_num.corr(),
            annot=True,        # show numbers in each cell
            cmap='coolwarm',   # color scheme (blue–red with white in middle)
            linewidths=0.5)    # thin lines between cells

plt.title("Heatmap - Correlation")
plt.show()

# %%
sns.violinplot(data=a, x='BMI', y='age',
               hue='male',        # split each violin by Gender
               split=True,          # put Male and Female on opposite sides of same violin
               inner='box',       # show quartiles inside violin (other options: 'box', 'stick')
               palette='husl')      # color palette

plt.title("Violin Plot - Score by Subject")
plt.xlabel("BMI")
plt.ylabel("age")
plt.show()

# %%
sns.violinplot(data=a, x='male', y='education',
               hue='male',        # split each violin by Gender
               split=True,          # put Male and Female on opposite sides of same violin
               inner='box',       # show quartiles inside violin (other options: 'box', 'stick')
               palette='husl')      # color palette

plt.title("Violin Plot - Score by Subject")
plt.xlabel("age")
plt.ylabel("education")
plt.show()

# %%
x=a.drop("TenYearCHD",axis=1)
y=a["TenYearCHD"]
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)

# %%
print(xtrain)

# %%
print(xtest)

# %%
print(ytrain)

# %%
print(ytest)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %%
# Impute missing values with the mean
imputer = SimpleImputer(strategy='mean') #impute module used to handle missing data. 'mean' specifies that missing values in the dataset should be replaced by the mean (average) value of the respective column.
x = imputer.fit_transform(x)

# %%
# Standardize features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.fit_transform(xtest)

# %%
print(xtrain)

# %%
print(xtest)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression()
model.fit(xtrain, ytrain)

# %%
ypred = model.predict(xtest)

# %%
# Calculate accuracy
accuracy = accuracy_score(ytest, ypred)
print(f'Accuracy: {accuracy * 100:.2f}%')

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate confusion matrix
cm = confusion_matrix(ytest, ypred)

# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['One', 'Zero'], yticklabels=['One', 'Zero'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix of TenYearCHD')

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(xtrain, ytrain)

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(ytest, ypred))

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(
    criterion='entropy',
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=5,
    max_features='sqrt',
    max_leaf_nodes=20,
    splitter='best',
    class_weight='balanced',
    random_state=42,
    ccp_alpha=0.01
)

# %%
model.fit(xtrain, ytrain)

# %%
ypred = model.predict(xtest)
print(model.criterion, accuracy_score(ytest, ypred))

# %%
from sklearn.metrics import accuracy_score

for crit in ['gini', 'entropy', 'log_loss']:
    model = DecisionTreeClassifier(criterion=crit)
    model.fit(xtrain, ytrain)
    ypred = model.predict(xtest)
    print(crit, accuracy_score(ytest, ypred))

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100)
model.fit(xtrain, ytrain)

# %%
ypred=model.predict(xtest)
print(accuracy_score(ytest,ypred))

# %%
# Generate confusion matrix
cm = confusion_matrix(ytest, ypred)

# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Survived', 'Survived'], yticklabels=['Not Survived', 'Survived'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix for Titanic Survival Prediction')

# %%
from sklearn.metrics import classification_report
ypred=model.predict(xtest)
print(classification_report(ytest,ypred))

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=1000)
model.fit(xtrain, ytrain)

# %%
ypred=model.predict(xtest)
print(classification_report(ytest,ypred))

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=5)
model.fit(xtrain, ytrain)

# %%
ypred=model.predict(xtest)
print(classification_report(ytest,ypred))

# %%
from sklearn.svm import SVC

model = SVC(kernel = 'rbf')
model.fit(xtrain, ytrain)

# %%
ypred=model.predict(xtest)
print(accuracy_score(ytest,ypred))

# %%
ypred=model.predict(xtest)
print(accuracy_score(ytest,ypred))

# %%
# Generate confusion matrix
cm = confusion_matrix(ytest, ypred)

# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Survived', 'Survived'], yticklabels=['Not Survived', 'Survived'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix for Titanic Survival Prediction')

# %%
from sklearn.metrics import classification_report
ypred=model.predict(xtest)
print(classification_report(ytest,ypred))

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(xtrain, ytrain)

# %%
ypred = model.predict(xtest)
print(accuracy_score(ytest,ypred))

# %%
# Generate confusion matrix
cm = confusion_matrix(ytest, ypred)

# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Survived', 'Survived'], yticklabels=['Not Survived', 'Survived'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix for Titanic Survival Prediction')

# %%
from sklearn.metrics import classification_report
ypred=model.predict(xtest)
print(classification_report(ytest,ypred))

# %%
model.predict_proba(xtest)

# %%
feature_names = a.drop('TenYearCHD', axis=1).columns

# %%
xtest_df = pd.DataFrame(xtest, columns=feature_names)

# %%
xtest_df['Predicted_Outcome'] = ypred

# %%
display(xtest_df.head())

# %%
x1=a.drop("TenYearCHD",axis=1)
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
print(x1)
x1_scaled = StandardScaler().fit_transform(x1)
print(x1_scaled)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
from sklearn.cluster import KMeans
wcss=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(x1_scaled)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [63600.000000000175,
#  54157.01916024059,
#  49226.15490731892,
#  46999.73241363642,
#  45130.682119841265,
#  44553.857484746055,
#  37750.42882991169,
#  36371.466221742034,
#  35067.46319201091,
#  33531.18617747075]

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,11),wcss)
plt.xticks(range(1,11))
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans=KMeans(n_clusters=6,init="k-means++")
kmeans.fit_predict(x1_scaled)
# Out:
# array([3, 0, 5, ..., 0, 4, 1], dtype=int32)

# %%
from sklearn.metrics import silhouette_score

silhouette_coefficients = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(x1_scaled)
    score = silhouette_score(x1_scaled, kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
silhouette_coefficients
# Out:
# [np.float64(0.20997121145185066),
#  np.float64(0.1269966785700701),
#  np.float64(0.1374317637788566),
#  np.float64(0.12591926097373118),
#  np.float64(0.12622691502458522),
#  np.float64(0.1592628673339822),
#  np.float64(0.13131298231476682),
#  np.float64(0.12600142211488422),
#  np.float64(0.14442241260660027)]

# %%
plt.plot(range(2,11),silhouette_coefficients)
plt.xticks(range(2,11))
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()

# %%
kmeans=KMeans(n_clusters=2,init="k-means++")
kmeans.fit_predict(x1_scaled)
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int32)
