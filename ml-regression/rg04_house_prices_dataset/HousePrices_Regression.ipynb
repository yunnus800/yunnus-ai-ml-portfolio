# %%
import pandas as pd
from pandas import isnull

# %%
a=pd.read_csv('house_prices.csv')
print(a)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
a.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
a.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
a.shape
# Out:
# (1460, 81)

# %%
a.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
a.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
object_cols_a = a.select_dtypes(include='object').columns.tolist()
print(object_cols_a)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
col=['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

for i in col:
  a[i]=le.fit_transform(a[i])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
sns.histplot(a['SalePrice'], kde=True)
plt.title("Distribution of Sale Price")
plt.show()

# %%
plt.figure(figsize=(15,8))
corr = a.corr(numeric_only=True)
sns.heatmap(corr, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.scatterplot(x=a['GrLivArea'], y=a['SalePrice'])
plt.title("Living Area vs Price")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=a['OverallQual'], y=a['SalePrice'])
plt.title("Overall Quality vs Price")
plt.show()

# %%
cols = ['SalePrice', 'GrLivArea', 'TotalBsmtSF', 'OverallQual']
sns.pairplot(a[cols])
plt.show()

# %%
sns.countplot(x=a['OverallQual'])
plt.title("Overall Quality Count")
plt.show()

# %%
sns.boxplot(x=a['SalePrice'])
plt.show()

# %%
sns.scatterplot(x=a['GarageArea'], y=a['GarageCars'])
plt.show()

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
#from sklearn.impute import SimpleImputer
#import numpy as np

# %%
#imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
#a=imputer.fit_transform(a)
#print(a)

# %%
#np.isnan(a).sum()

# %%
x=a.drop("SalePrice",axis=1)
y=a["SalePrice"]

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# %%
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
x=imputer.fit_transform(x)
print(x)
# Out:
# [[1.000e+00 6.000e+01 3.000e+00 ... 2.008e+03 8.000e+00 4.000e+00]
#  [2.000e+00 2.000e+01 3.000e+00 ... 2.007e+03 8.000e+00 4.000e+00]
#  [3.000e+00 6.000e+01 3.000e+00 ... 2.008e+03 8.000e+00 4.000e+00]
#  ...
#  [1.458e+03 7.000e+01 3.000e+00 ... 2.010e+03 8.000e+00 4.000e+00]
#  [1.459e+03 2.000e+01 3.000e+00 ... 2.010e+03 8.000e+00 4.000e+00]
#  [1.460e+03 2.000e+01 3.000e+00 ... 2.008e+03 8.000e+00 4.000e+00]]

# %%
np.isnan(x).sum()
# Out:
# np.int64(0)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# Create and train the model
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, median_absolute_error
import numpy as np

# %%
print("MAE:", mean_absolute_error(ytest, ypred))
# Out:
# MAE: 19941.692742964184

# %%
print("RMSE:", np.sqrt(mean_squared_error(ytest, ypred)))
# Out:
# RMSE: 31378.923688687766

# %%
print("R²:", r2_score(ytest, ypred))
# Out:
# R²: 0.8315992845981395

# %%
med_ae = median_absolute_error(ytest, ypred)
print("Median Absolute Error:", med_ae)
# Out:
# Median Absolute Error: 13327.925240266719

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
model = DecisionTreeRegressor(
    criterion='poisson',
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=5,
    max_features='sqrt',
    max_leaf_nodes=20,
    splitter='best',
    #class_weight='balanced',
    random_state=42,
    ccp_alpha=0.01
)
model.fit(xtrain, ytrain)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.01, criterion='poisson', max_depth=5,
#                       max_features='sqrt', max_leaf_nodes=20,
#                       min_samples_leaf=5, min_samples_split=10,
#                       random_state=42)

# %%
ypred=model.predict(xtest)

# %%
print(mean_absolute_error(ytest, ypred))
# Out:
# 29117.961725193116

# %%
print(mean_squared_error(ytest, ypred))
# Out:
# 1657157782.9486246

# %%
print(r2_score(ytest, ypred))
# Out:
# 0.7165792082075662

# %%
model = DecisionTreeRegressor(
    criterion='friedman_mse',
    max_depth=500,
    min_samples_split=100,
    min_samples_leaf=50,
    max_features='sqrt',
    max_leaf_nodes=200,
    splitter='best',
    #class_weight='balanced',
    random_state=42,
    ccp_alpha=0.01
)
model.fit(xtrain, ytrain)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.01, criterion='friedman_mse', max_depth=500,
#                       max_features='sqrt', max_leaf_nodes=200,
#                       min_samples_leaf=50, min_samples_split=100,
#                       random_state=42)

# %%
ypred=model.predict(xtest)

# %%
print(mean_absolute_error(ytest, ypred))
# Out:
# 34545.0732334415

# %%
print(mean_squared_error(ytest, ypred))
# Out:
# 2365876270.4905305

# %%
print(r2_score(ytest, ypred))
# Out:
# 0.5953683271654135

# %%
#RandomForestRegressor

model = RandomForestRegressor(n_estimators=100)
model.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor()

# %%
ypred=model.predict(xtest)

# %%
print("MAE - ", mean_absolute_error(ytest, ypred))
print("MSE - ", mean_squared_error(ytest, ypred))
print("R2  - ", r2_score(ytest, ypred))
# Out:
# MAE -  18000.11085616438
# MSE -  762650358.9867907
# R2  -  0.8695652454890463

# %%
model = RandomForestRegressor(n_estimators=1000)
model.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
ypred=model.predict(xtest)

# %%
print("MAE - ", mean_absolute_error(ytest, ypred))
print("MSE - ", mean_squared_error(ytest, ypred))
print("R2  - ", r2_score(ytest, ypred))
# Out:
# MAE -  18401.628188356164
# MSE -  790398952.6151919
# R2  -  0.8648194521444352

# %%
model = RandomForestRegressor(n_estimators=2, criterion='poisson')
model.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor(criterion='poisson', n_estimators=2)

# %%
print("MAE - ", mean_absolute_error(ytest, ypred))
print("MSE - ", mean_squared_error(ytest, ypred))
print("R2  - ", r2_score(ytest, ypred))
# Out:
# MAE -  18401.628188356164
# MSE -  790398952.6151919
# R2  -  0.8648194521444352
