# %%
import pandas as pd
from pandas import isnull

# %%
a=pd.read_csv("housing.csv")
print(a)
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %%
a.shape
# Out:
# (489, 4)

# %%
a.isnull().sum()
# Out:
# RM         0
# LSTAT      0
# PTRATIO    0
# MEDV       0
# dtype: int64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RM       489 non-null    float64
#  1   LSTAT    489 non-null    float64
#  2   PTRATIO  489 non-null    float64
#  3   MEDV     489 non-null    float64
# dtypes: float64(4)
# memory usage: 15.4 KB

# %%
X = a.drop("MEDV",axis=1)  # Replace 'X' with your actual column name
Y = a['MEDV']    # Replace 'Y' with your actual column name

# %%
# Split into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# Create and train the model
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, median_absolute_error
import numpy as np

# %%
print("MAE:", mean_absolute_error(Y_test, Y_pred))
# Out:
# MAE: 64277.28865670341

# %%
print("RMSE:", np.sqrt(mean_squared_error(Y_test, Y_pred)))
# Out:
# RMSE: 82395.54332162566

# %%
print("R²:", r2_score(Y_test, Y_pred))
# Out:
# R²: 0.691093400309851

# %%
med_ae = median_absolute_error(Y_test, Y_pred)
print("Median Absolute Error:", med_ae)
# Out:
# Median Absolute Error: 57264.040860707

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
model = DecisionTreeRegressor(
    criterion='poisson',
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=5,
    max_features='sqrt',
    max_leaf_nodes=20,
    splitter='best',
    #class_weight='balanced',
    random_state=42,
    ccp_alpha=0.01
)
model.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.01, criterion='poisson', max_depth=5,
#                       max_features='sqrt', max_leaf_nodes=20,
#                       min_samples_leaf=5, min_samples_split=10,
#                       random_state=42)

# %%
ypred=model.predict(X_test)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  56811.9919031289
# MSE -  5335432887.622183
# R2  -  0.7572331379809125

# %%
model = DecisionTreeRegressor(
    criterion='friedman_mse',
    max_depth=500,
    min_samples_split=100,
    min_samples_leaf=50,
    max_features='sqrt',
    max_leaf_nodes=200,
    splitter='best',
    #class_weight='balanced',
    random_state=42,
    ccp_alpha=0.01
)
model.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.01, criterion='friedman_mse', max_depth=500,
#                       max_features='sqrt', max_leaf_nodes=200,
#                       min_samples_leaf=50, min_samples_split=100,
#                       random_state=42)

# %%
ypred=model.predict(X_test)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  76866.16386457907
# MSE -  9680866057.109795
# R2  -  0.5595121288538893

# %%
model = RandomForestRegressor(n_estimators=1000)
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
ypred=model.predict(X_test)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  44440.90714285715
# MSE -  3343273251.8849993
# R2  -  0.8478781434744671

# %%
model = RandomForestRegressor(n_estimators=2, criterion='poisson')
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(criterion='poisson', n_estimators=2)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  44440.90714285715
# MSE -  3343273251.8849993
# R2  -  0.8478781434744671
