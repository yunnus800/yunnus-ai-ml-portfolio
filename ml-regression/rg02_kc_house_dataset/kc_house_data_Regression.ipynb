# %%
import pandas as pd
from pandas import isnull

# %%
a=pd.read_csv("kc_house_data.csv")
print(a)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
a.shape
# Out:
# (21613, 21)

# %%
a.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
a.duplicated().sum()
# Out:
# np.int64(0)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
a['date']=le.fit_transform(a['date'])

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  int64
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(16)
# memory usage: 3.5 MB

# %%
X = a.drop("price",axis=1)  # Replace 'X' with your actual column name
Y = a['price']    # Replace 'Y' with your actual column name

# %%
# Split into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# Create and train the model
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, median_absolute_error
import numpy as np

# %%
print("MAE:", mean_absolute_error(Y_test, Y_pred))
# Out:
# MAE: 127168.02695969486

# %%
print("RMSE:", np.sqrt(mean_squared_error(Y_test, Y_pred)))
# Out:
# RMSE: 212104.4497556145

# %%
print("R²:", r2_score(Y_test, Y_pred))
# Out:
# R²: 0.7024125149004783

# %%
med_ae = median_absolute_error(Y_test, Y_pred)
print("Median Absolute Error:", med_ae)
# Out:
# Median Absolute Error: 86634.25540013798

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
model = DecisionTreeRegressor(
    criterion='poisson',
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=5,
    max_features='sqrt',
    max_leaf_nodes=20,
    splitter='best',
    #class_weight='balanced',
    random_state=42,
    ccp_alpha=0.01
)
model.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.01, criterion='poisson', max_depth=5,
#                       max_features='sqrt', max_leaf_nodes=20,
#                       min_samples_leaf=5, min_samples_split=10,
#                       random_state=42)

# %%
ypred=model.predict(X_test)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  151856.81211846182
# MSE -  75566848376.38274
# R2  -  0.5001422689495258

# %%
model = DecisionTreeRegressor(
    criterion='friedman_mse',
    max_depth=500,
    min_samples_split=100,
    min_samples_leaf=50,
    max_features='sqrt',
    max_leaf_nodes=200,
    splitter='best',
    #class_weight='balanced',
    random_state=42,
    ccp_alpha=0.01
)
model.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.01, criterion='friedman_mse', max_depth=500,
#                       max_features='sqrt', max_leaf_nodes=200,
#                       min_samples_leaf=50, min_samples_split=100,
#                       random_state=42)

# %%
ypred=model.predict(X_test)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  127640.4904032436
# MSE -  56950543452.4012
# R2  -  0.623284945133352

# %%
#model = RandomForestRegressor(n_estimators=1000)
#model.fit(X_train, Y_train)

# %%
#ypred=model.predict(X_test)

# %%
#print("MAE - ", mean_absolute_error(Y_test, ypred))
#print("MSE - ", mean_squared_error(Y_test, ypred))
#print("R2  - ", r2_score(Y_test, ypred))

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
ypred=model.predict(X_test)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  72803.01985195465
# MSE -  21299159776.24262
# R2  -  0.8591108414895654

# %%
model = RandomForestRegressor(n_estimators=3)
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(n_estimators=3)

# %%
ypred=model.predict(X_test)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  88049.28151746473
# MSE -  37700021005.31179
# R2  -  0.7506228277986517

# %%
from sklearn.svm import SVR

model = SVR(kernel='sigmoid', C=1.0, epsilon=0.2)
model.fit(X_train, Y_train)
# Out:
# SVR(epsilon=0.2, kernel='sigmoid')

# %%
ypred=model.predict(X_test)

print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  229736.8914387759
# MSE -  161052322970.94803
# R2  -  -0.06532494698860969

# %%
from sklearn.svm import SVR

model = SVR(kernel='rbf', C=1.0, epsilon=0.2)
model.fit(X_train, Y_train)
# Out:
# SVR(epsilon=0.2)

# %%
ypred=model.predict(X_test)

print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  229734.9374046354
# MSE -  161049660434.67175
# R2  -  -0.06530733490910001
