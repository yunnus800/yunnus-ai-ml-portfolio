# %%
import pandas as pd
from pandas import isnull

# %%
a=pd.read_csv("advertising.csv")
print(a)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
a.shape
# Out:
# (200, 4)

# %%
a.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
X = a.drop("Sales",axis=1)  # Replace 'X' with your actual column name
Y = a['Sales']    # Replace 'Y' with your actual column name

# %%
# Split into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# Create and train the model
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
print("MAE:", mean_absolute_error(Y_test, Y_pred))
# Out:
# MAE: 1.2748262109549338

# %%
print("RMSE:", np.sqrt(mean_squared_error(Y_test, Y_pred)))
# Out:
# RMSE: 1.7052146229349223

# %%
print("R²:", r2_score(Y_test, Y_pred))
# Out:
# R²: 0.9059011844150826

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
model = DecisionTreeRegressor(
    criterion='poisson',
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=5,
    max_features='sqrt',
    max_leaf_nodes=20,
    splitter='best',
    #class_weight='balanced',
    random_state=42,
    ccp_alpha=0.01
)
model.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.01, criterion='poisson', max_depth=5,
#                       max_features='sqrt', max_leaf_nodes=20,
#                       min_samples_leaf=5, min_samples_split=10,
#                       random_state=42)

# %%
ypred=model.predict(X_test)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  1.3514546383848702
# MSE -  3.1605474061912378
# R2  -  0.8977205534368926

# %%
model = DecisionTreeRegressor(
    criterion='friedman_mse',
    max_depth=500,
    min_samples_split=100,
    min_samples_leaf=50,
    max_features='sqrt',
    max_leaf_nodes=200,
    splitter='best',
    #class_weight='balanced',
    random_state=42,
    ccp_alpha=0.01
)
model.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.01, criterion='friedman_mse', max_depth=500,
#                       max_features='sqrt', max_leaf_nodes=200,
#                       min_samples_leaf=50, min_samples_split=100,
#                       random_state=42)

# %%
ypred=model.predict(X_test)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  4.624149742101869
# MSE -  29.836205514832887
# R2  -  0.03446137791752113

# %%
model = RandomForestRegressor(n_estimators=1000)
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
ypred=model.predict(X_test)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  0.8935975000000095
# MSE -  1.4074682642500158
# R2  -  0.9544524866671408

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
ypred=model.predict(X_test)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  0.9178000000000001
# MSE -  1.4516597000000018
# R2  -  0.9530223940248082

# %%
model = RandomForestRegressor(n_estimators=3)
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(n_estimators=3)

# %%
ypred=model.predict(X_test)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  0.9983333333333333
# MSE -  1.610444444444444
# R2  -  0.9478839120793614

# %%
from sklearn.svm import SVR

model = SVR(kernel='rbf', C=1.0, epsilon=0.2)
model.fit(X_train, Y_train)
# Out:
# SVR(epsilon=0.2)

# %%
ypred=model.predict(X_test)

# %%
print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  1.5073810200118438
# MSE -  3.5412483294092367
# R2  -  0.8854005737851003

# %%
from sklearn.svm import SVR

model = SVR(kernel='sigmoid', C=1.0, epsilon=0.2)
model.fit(X_train, Y_train)
# Out:
# SVR(epsilon=0.2, kernel='sigmoid')

# %%
ypred=model.predict(X_test)

print("MAE - ", mean_absolute_error(Y_test, ypred))
print("MSE - ", mean_squared_error(Y_test, ypred))
print("R2  - ", r2_score(Y_test, ypred))
# Out:
# MAE -  7.559306453865261
# MSE -  76.36306790534464
# R2  -  -1.4712087241342426
